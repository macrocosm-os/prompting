# %%
import wandb
import pandas as pd

api = wandb.Api()
run_id = "cp0uf8du"
run = api.run(f"/opentensor-dev/synapse_agent_experiments/runs/{run_id}")

df = pd.DataFrame(list(run.scan_history()))
df
# Out:
#    reference_length_words                                          challenge  \
# 0                      73  Can you provide a concise summary of the Caiss...
# 1                      72  Hi AI assistant, as I'm feeling tired and need...
#
#                                            reference           name  _step  \
# 0  The Caisse Noire Affair exposed illegal practi...  summarization      0
# 1  The Caisse Noire Affair, a long-standing scand...  summarization      1
#
#     model                         desc  gpt_reference_time  \
# 0  zephyr  get help with summarization           21.524860
# 1  zephyr  get help with summarization           18.769174
#
#    challenge_eval_score  reference_from_challenge_eval_score  ...  \
# 0                     1                                    1  ...
# 1                     1                                    1  ...
#
#                                                 goal challenge_length_chars  \
# ...

# %%
from pprint import pprint


pprint(df['roleplay_system_prompt'].iloc[0])
pprint(df['challenge'].iloc[0])
pprint(df['reference'].iloc[0])
